# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.kernel_ridge import KernelRidge
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import glob
import os

# %%
# Redefinir pd.read_csv e pd.concat para as funções originais
pd.read_csv = pd.io.parsers.read_csv
pd.concat = pd.core.reshape.concat.concat

# %%
normal = "D:/Vibração - Projeto/Códigos/Mafaulda/"

# %%
arquivos_csv = glob.glob(os.path.join(normal, "*.csv"))

# %%
# Carregar e concatenar todos os arquivos CSV em um único DataFrame
df_normal = pd.concat((pd.read_csv(f) for f in arquivos_csv), ignore_index=True)

# Exibir as primeiras linhas do DataFrame resultante
print(df_normal.head())
# Out:
#    -0.6047  -0.21439  0.055384  0.015957  0.83268  -0.034527  0.55998  \
# 0 -0.60753  0.041574  -0.78641 -0.050803  0.80750  -0.033898  0.56886
# 1 -0.61020 -1.250400  -0.22414 -0.027880  0.80616  -0.033564  0.59887
# 2 -0.55453  0.867320  -0.41724 -0.030147  0.83614  -0.032794  0.62705
# 3 -0.60909 -1.521800  -0.52573 -0.072589  0.81438  -0.035515  0.61234
# 4 -0.52106  1.105200  -0.17698  0.002443  0.87121  -0.038249  0.67202
#
#    -0.21349
# 0  0.322190
# 1 -0.153860
# 2  0.180320
# 3  0.006037
# 4 -0.010147

# %%
print("Tamanho data_dir:", len(normal))
print("Tamanho do dataset:", df_normal.shape)
print("--------------------")
df_normal.info()
# Out:
# Tamanho data_dir: 39
# Tamanho do dataset: (249999, 8)
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249999 entries, 0 to 249998
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   -0.6047    249999 non-null  float64
#  1   -0.21439   249999 non-null  float64
#  2   0.055384   249999 non-null  float64
#  3   0.015957   249999 non-null  float64
#  4   0.83268    249999 non-null  float64
#  5   -0.034527  249999 non-null  float64
#  6   0.55998    249999 non-null  float64
#  7   -0.21349   249999 non-null  float64
# dtypes: float64(8)
# memory usage: 15.3 MB

# %%
print(df_normal.columns)
# Out:
# Index(['-0.6047', '-0.21439', '0.055384', '0.015957', '0.83268', '-0.034527',
#        '0.55998', '-0.21349'],
#       dtype='object')

# %% [markdown]
# ### Trabalhando o arquivo Normal 28.8768.csv:

# %%
# Caminho para o arquivo CSV específico
arquivo_01_csv = "c:/Mafaulda/normal/28.8768.csv"

# Carregar o arquivo CSV específico
df_arquivo_01_csv = pd.read_csv(arquivo_01_csv)

# Exibir as primeiras linhas do DataFrame resultante
print(df_arquivo_01_csv.head())
# Out:
#    -0.6047  -0.21439  0.055384  0.015957  0.83268  -0.034527  0.55998  \
# 0 -0.60753  0.041574  -0.78641 -0.050803  0.80750  -0.033898  0.56886
# 1 -0.61020 -1.250400  -0.22414 -0.027880  0.80616  -0.033564  0.59887
# 2 -0.55453  0.867320  -0.41724 -0.030147  0.83614  -0.032794  0.62705
# 3 -0.60909 -1.521800  -0.52573 -0.072589  0.81438  -0.035515  0.61234
# 4 -0.52106  1.105200  -0.17698  0.002443  0.87121  -0.038249  0.67202
#
#    -0.21349
# 0  0.322190
# 1 -0.153860
# 2  0.180320
# 3  0.006037
# 4 -0.010147

# %% [markdown]
# ### Colunas:
#
# - column 1: tachometer signal that allows to estimate rotation frequency - TS;
#
# - columns 2 to 4: underhang bearing accelerometer - UBA (axial, radiale tangential direction);
#
# - columns 5 to 7: overhang bearing accelerometer - OBA (axial, radiale tangential direction);
#
# - column 8 - microphone - MIC.

# %%
nomes_colunas = ['TS', 'UBA_01', 'UBA_02', 'UBA_03', 'OBA_01', 'OBA_02', 'OBA_03', 'MIC']
arquivo_01_csv = "c:/Mafaulda/normal/28.8768.csv"
df_arquivo_01_csv = pd.read_csv(arquivo_01_csv, header=None, names=nomes_colunas)

# %%
print(df_arquivo_01_csv.head())
print(df_arquivo_01_csv.describe())
# Out:
#         TS    UBA_01    UBA_02    UBA_03   OBA_01    OBA_02   OBA_03       MIC
# 0 -0.60470 -0.214390  0.055384  0.015957  0.83268 -0.034527  0.55998 -0.213490
# 1 -0.60753  0.041574 -0.786410 -0.050803  0.80750 -0.033898  0.56886  0.322190
# 2 -0.61020 -1.250400 -0.224140 -0.027880  0.80616 -0.033564  0.59887 -0.153860
# 3 -0.55453  0.867320 -0.417240 -0.030147  0.83614 -0.032794  0.62705  0.180320
# 4 -0.60909 -1.521800 -0.525730 -0.072589  0.81438 -0.035515  0.61234  0.006037
#                   TS         UBA_01         UBA_02         UBA_03  \
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean       -0.000823       0.011256      -0.000614       0.000245
# std         1.690908       0.976044       0.369580       0.107508
# min        -1.323900      -3.992000      -1.969600      -0.581280
# 25%        -0.672030      -0.735043      -0.261690      -0.072166
# 50%        -0.634830       0.144030       0.021365      -0.001167
# 75%        -0.545007       0.847550       0.282463       0.071213
# max         5.000000       2.107400       1.718500       0.497900
#
#               OBA_01         OBA_02         OBA_03            MIC
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean       -0.001565       0.003696       0.005187       0.013926
# std         0.638788       0.028810       0.352200       0.154999
# min        -2.289000      -0.082350      -1.317400      -0.348270
# 25%        -0.460363      -0.019587      -0.246860      -0.115940
# 50%         0.008290       0.004645       0.000286      -0.004647
# 75%         0.472850       0.027402       0.247512       0.124660
# max         1.851500       0.074134       1.524100       0.719190

# %%
import matplotlib.pyplot as plt
df_arquivo_01_csv['TS'].hist(bins=30)
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.title('Distribuição de Frequências')
plt.show()

# %%
df_arquivo_01_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   TS      250000 non-null  float64
#  1   UBA_01  250000 non-null  float64
#  2   UBA_02  250000 non-null  float64
#  3   UBA_03  250000 non-null  float64
#  4   OBA_01  250000 non-null  float64
#  5   OBA_02  250000 non-null  float64
#  6   OBA_03  250000 non-null  float64
#  7   MIC     250000 non-null  float64
# dtypes: float64(8)
# memory usage: 15.3 MB

# %%
df_arquivo_01_csv.isnull().sum()
# Out:
# TS        0
# UBA_01    0
# UBA_02    0
# UBA_03    0
# OBA_01    0
# OBA_02    0
# OBA_03    0
# MIC       0
# dtype: int64

# %%
df_arquivo_01_csv.corr()
# Out:
#               TS    UBA_01    UBA_02    UBA_03    OBA_01    OBA_02    OBA_03  \
# TS      1.000000  0.003922  0.116471 -0.071884  0.092069  0.043787  0.011877
# UBA_01  0.003922  1.000000  0.446640  0.297291  0.036124  0.016094  0.087737
# UBA_02  0.116471  0.446640  1.000000  0.273501  0.077391  0.050768  0.116031
# UBA_03 -0.071884  0.297291  0.273501  1.000000  0.064715  0.031038  0.026294
# OBA_01  0.092069  0.036124  0.077391  0.064715  1.000000  0.227160  0.735330
# OBA_02  0.043787  0.016094  0.050768  0.031038  0.227160  1.000000  0.203539
# OBA_03  0.011877  0.087737  0.116031  0.026294  0.735330  0.203539  1.000000
# MIC    -0.010920 -0.112417 -0.657123 -0.289000 -0.041249 -0.030873 -0.065529
#
#              MIC
# TS     -0.010920
# UBA_01 -0.112417
# UBA_02 -0.657123
# UBA_03 -0.289000
# OBA_01 -0.041249
# OBA_02 -0.030873
# OBA_03 -0.065529
# MIC     1.000000

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(8, 12))
axes = axes.flatten()
for i, col in enumerate(df_arquivo_01_csv.columns[:8]):  # Limitando às primeiras 9 colunas
    df_arquivo_01_csv[col].hist(ax=axes[i], bins=40)
    axes[i].set_title(col)

#df_arquivo_01_csv.hist()
plt.show()

# %% [markdown]
# ### Abordando o problema de forma não supervisionada:
#
# - Uso de autoencoder tanto no SBM como no AAKR, adapatados para funcionar como modelos de aprendizado não supervisionado. Prevendo padrões ou anomalias nos dados (análise auto-associativa):

# %%
df = df_arquivo_01_csv

X = df[['TS', 'UBA_01', 'UBA_02', 'UBA_03', 'OBA_01', 'OBA_02', 'OBA_03', 'MIC']]

# %%
# Exemplo de dados para X (substitua pelos seus dados reais)
X = np.random.rand(220000, 1)  # Exemplo de 1000 amostras, 1 característica

X = X.reshape((-1, 1))

# Separação desenvolvimento (30) e teste (70)
X_dev, X_test = train_test_split(X, test_size=0.8, random_state=42)

# Separação treino (80) e validação (20) - Hold-out
X_train, X_val, = train_test_split(X_dev, test_size=0.8, random_state=42)

# Normalizando dados para treino, validação e teste
X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

# Exibir as formas dos conjuntos de dados
print("Shape do conjunto de treino:", X_train.shape)
print("Shape do conjunto de validação:", X_val.shape)
print("Shape do conjunto de teste:", X_test.shape)
# Out:
# Shape do conjunto de treino: (8800, 1)
# Shape do conjunto de validação: (35200, 1)
# Shape do conjunto de teste: (176000, 1)

# %%
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Dense, Dropout

# Autoencoder simples para SBM
def create_sbm_autoencoder(input_shape):
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,)),
        Dropout(0.50),  # Dropout após a primeira camada
        Dense(32, activation='relu'),  # Encoder
        Dropout(0.50),  # Dropout após o Encoder
        Dense(64, activation='relu'),  # Decoder
        Dropout(0.50),  # Dropout após o Decoder
        #Dense(input_shape)  # Saída de mesma dimensão que a entrada
        Dense(input_shape,)
    ])
    model.compile(optimizer='adam', loss='mse')  # Usar MAE para medir o erro
    return model

# %%
from tensorflow.keras.regularizers import l2

# %%
def create_aakr_autoencoder(input_shape):
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,), kernel_regularizer=l2(0.01)),
        Dropout(0.5),
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),  # Encoder
        Dropout(0.5),
        Dense(64, activation='relu', kernel_regularizer=l2(0.01)),  # Decoder
        Dropout(0.5),
        Dense(input_shape, kernel_regularizer=l2(0.01))  # Saída de mesma dimensão que a entrada
    ])
    create_aakr_autoencoder.compile(optimizer='adam', loss='mse')  # Usar MSE para medir o erro
    return model

# %%
# Função para aplicar o AAKR (Auto-Associative Kernel Regression)
def apply_aakr(X_train, X_test, kernel='rbf'):
    # Definir o modelo AAKR usando Kernel Ridge Regression
    aakr_model = KernelRidge(kernel=kernel)
    
    # Treinar o modelo AAKR no conjunto de treino
    aakr_model.fit(X_train, X_train)
    
    # Fazer previsões para o conjunto de teste
    X_pred_aakr = aakr_model.predict(X_test)
    
    # Calcular erro de reconstrução do AAKR
    aakr_value = mean_squared_error(X_test, X_pred_aakr)
    return X_pred_aakr, aakr_value

# %%
# Callback personalizado para acompanhar a acurácia
class AccuracyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        accuracy = 1 - loss
        val_accuracy = 1 - val_loss
        print(f"Epoch {epoch+1}: Perda Treinamento: {loss:.4f}, Acurácia Treinamento: {accuracy:.4f}, Perda Validação: {val_loss:.4f}, Acurácia Validação: {val_accuracy:.4f}")
        
        

# Criar o autoencoder e atribuir à variável 'sbm_autoencoder'
sbm_autoencoder = create_sbm_autoencoder(X_train.shape[1])

# Exibir o sumário do modelo
sbm_autoencoder.summary()
# Out:
# c:\Users\Carlos Carneiro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - A acurácia de um autoencoder geralmente é medida com base no erro de reconstrução:

# %%
# Treinar o modelo SBM e armazenar o histórico de treinamento
history = sbm_autoencoder.fit(
    X_train, X_train,
    epochs=30,
    batch_size=128,
    validation_data=(X_val, X_val),
    callbacks=[AccuracyCallback()],  # "AccuracyCallback" com 'C' maiúsculo
    verbose=1
)

#Treinamento AAKR:

history = aakr_autoencoder.fit(
    X_train, X_train,
    epochs=20,  # Reduzir número de épocas
    batch_size=64,  # Diminuir tamanho do batch
    validation_data=(X_val, X_val),
    callbacks=[AccuracyCallback()],
    verbose=1
)

# Fazer previsões com o Autoencoder SBM
X_pred_sbm = sbm_autoencoder.predict(X_test)
sbm_value = np.mean(np.abs(X_test - X_pred_sbm))  # Erro médio absoluto como SBM

# Calcular "acurácia" inversamente proporcional ao erro de reconstrução (quanto menor o erro, melhor a acurácia)
accuracy = 1 - sbm_value

# Aplicar o AAKR e calcular o erro
X_pred_aakr, aakr_value = apply_aakr(X_train, X_test)
X_pred_sbm = sbm_autoencoder.predict(X_test)
sbm_value = np.mean(np.abs(X_test - X_pred_sbm))  # Erro médio absoluto como SBM

# Calcular acurácias
accuracy_sbm = 1 - sbm_value
accuracy_aakr = 1 - aakr_value
# Out:
# Epoch 1/50
# 61/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1348Epoch 1: Perda Treinamento: 0.0841, Acurácia Treinamento: 0.9159, Perda Validação: 0.0285, Acurácia Validação: 0.9715
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1285 - val_loss: 0.0285
# Epoch 2/50
# 50/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400Epoch 2: Perda Treinamento: 0.0364, Acurácia Treinamento: 0.9636, Perda Validação: 0.0182, Acurácia Validação: 0.9818
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0392 - val_loss: 0.0182
# Epoch 3/50
# 54/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316Epoch 3: Perda Treinamento: 0.0306, Acurácia Treinamento: 0.9694, Perda Validação: 0.0242, Acurácia Validação: 0.9758
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0314 - val_loss: 0.0242
# Epoch 4/50
# 52/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0276Epoch 4: Perda Treinamento: 0.0266, Acurácia Treinamento: 0.9734, Perda Validação: 0.0272, Acurácia Validação: 0.9728
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0274 - val_loss: 0.0272
# Epoch 5/50
# 54/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243Epoch 5: Perda Treinamento: 0.0242, Acurácia Treinamento: 0.9758, Perda Validação: 0.0223, Acurácia Validação: 0.9777
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243 - val_loss: 0.0223
# Epoch 6/50
# 49/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0251Epoch 6: Perda Treinamento: 0.0240, Acurácia Treinamento: 0.9760, Perda Validação: 0.0244, Acurácia Validação: 0.9756
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0248 - val_loss: 0.0244
# Epoch 7/50
# 64/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0214Epoch 7: Perda Treinamento: 0.0215, Acurácia Treinamento: 0.9785, Perda Validação: 0.0329, Acurácia Validação: 0.9671
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0214 - val_loss: 0.0329
# Epoch 8/50
# 65/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221Epoch 8: Perda Treinamento: 0.0218, Acurácia Treinamento: 0.9782, Perda Validação: 0.0264, Acurácia Validação: 0.9736
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0221 - val_loss: 0.0264
# Epoch 9/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201Epoch 9: Perda Treinamento: 0.0207, Acurácia Treinamento: 0.9793, Perda Validação: 0.0240, Acurácia Validação: 0.9760
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0202 - val_loss: 0.0240
# Epoch 10/50
# 51/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198Epoch 10: Perda Treinamento: 0.0199, Acurácia Treinamento: 0.9801, Perda Validação: 0.0208, Acurácia Validação: 0.9792
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - val_loss: 0.0208
# Epoch 11/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196Epoch 11: Perda Treinamento: 0.0194, Acurácia Treinamento: 0.9806, Perda Validação: 0.0206, Acurácia Validação: 0.9794
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0196 - val_loss: 0.0206
# Epoch 12/50
# 62/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193Epoch 12: Perda Treinamento: 0.0193, Acurácia Treinamento: 0.9807, Perda Validação: 0.0278, Acurácia Validação: 0.9722
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0193 - val_loss: 0.0278
# Epoch 13/50
# 46/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195Epoch 13: Perda Treinamento: 0.0186, Acurácia Treinamento: 0.9814, Perda Validação: 0.0250, Acurácia Validação: 0.9750
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0192 - val_loss: 0.0250
# Epoch 14/50
# 59/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195Epoch 14: Perda Treinamento: 0.0190, Acurácia Treinamento: 0.9810, Perda Validação: 0.0340, Acurácia Validação: 0.9660
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0194 - val_loss: 0.0340
# Epoch 15/50
# 55/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187Epoch 15: Perda Treinamento: 0.0187, Acurácia Treinamento: 0.9813, Perda Validação: 0.0269, Acurácia Validação: 0.9731
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0187 - val_loss: 0.0269
# Epoch 16/50
# 58/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195Epoch 16: Perda Treinamento: 0.0183, Acurácia Treinamento: 0.9817, Perda Validação: 0.0320, Acurácia Validação: 0.9680
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0193 - val_loss: 0.0320
# Epoch 17/50
# 62/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184Epoch 17: Perda Treinamento: 0.0187, Acurácia Treinamento: 0.9813, Perda Validação: 0.0370, Acurácia Validação: 0.9630
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0184 - val_loss: 0.0370
# Epoch 18/50
# 63/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191Epoch 18: Perda Treinamento: 0.0183, Acurácia Treinamento: 0.9817, Perda Validação: 0.0310, Acurácia Validação: 0.9690
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0190 - val_loss: 0.0310
# Epoch 19/50
# 66/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179Epoch 19: Perda Treinamento: 0.0178, Acurácia Treinamento: 0.9822, Perda Validação: 0.0307, Acurácia Validação: 0.9693
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0179 - val_loss: 0.0307
# Epoch 20/50
# 61/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185Epoch 20: Perda Treinamento: 0.0185, Acurácia Treinamento: 0.9815, Perda Validação: 0.0350, Acurácia Validação: 0.9650
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0185 - val_loss: 0.0350
# Epoch 21/50
# 61/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177Epoch 21: Perda Treinamento: 0.0176, Acurácia Treinamento: 0.9824, Perda Validação: 0.0341, Acurácia Validação: 0.9659
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0176 - val_loss: 0.0341
# Epoch 22/50
# 56/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178Epoch 22: Perda Treinamento: 0.0180, Acurácia Treinamento: 0.9820, Perda Validação: 0.0321, Acurácia Validação: 0.9679
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0178 - val_loss: 0.0321
# Epoch 23/50
# 54/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183Epoch 23: Perda Treinamento: 0.0179, Acurácia Treinamento: 0.9821, Perda Validação: 0.0358, Acurácia Validação: 0.9642
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0182 - val_loss: 0.0358
# Epoch 24/50
# 68/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174Epoch 24: Perda Treinamento: 0.0174, Acurácia Treinamento: 0.9826, Perda Validação: 0.0315, Acurácia Validação: 0.9685
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0174 - val_loss: 0.0315
# Epoch 25/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174Epoch 25: Perda Treinamento: 0.0173, Acurácia Treinamento: 0.9827, Perda Validação: 0.0375, Acurácia Validação: 0.9625
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0174 - val_loss: 0.0375
# Epoch 26/50
# 68/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171Epoch 26: Perda Treinamento: 0.0177, Acurácia Treinamento: 0.9823, Perda Validação: 0.0394, Acurácia Validação: 0.9606
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0171 - val_loss: 0.0394
# Epoch 27/50
# 66/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169Epoch 27: Perda Treinamento: 0.0170, Acurácia Treinamento: 0.9830, Perda Validação: 0.0414, Acurácia Validação: 0.9586
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0170 - val_loss: 0.0414
# Epoch 28/50
# 50/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174Epoch 28: Perda Treinamento: 0.0173, Acurácia Treinamento: 0.9827, Perda Validação: 0.0400, Acurácia Validação: 0.9600
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0174 - val_loss: 0.0400
# Epoch 29/50
# 44/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175Epoch 29: Perda Treinamento: 0.0174, Acurácia Treinamento: 0.9826, Perda Validação: 0.0385, Acurácia Validação: 0.9615
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0175 - val_loss: 0.0385
# Epoch 30/50
# 62/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173Epoch 30: Perda Treinamento: 0.0178, Acurácia Treinamento: 0.9822, Perda Validação: 0.0339, Acurácia Validação: 0.9661
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0174 - val_loss: 0.0339
# Epoch 31/50
# 65/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172Epoch 31: Perda Treinamento: 0.0173, Acurácia Treinamento: 0.9827, Perda Validação: 0.0373, Acurácia Validação: 0.9627
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0172 - val_loss: 0.0373
# Epoch 32/50
# 46/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174Epoch 32: Perda Treinamento: 0.0176, Acurácia Treinamento: 0.9824, Perda Validação: 0.0373, Acurácia Validação: 0.9627
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0175 - val_loss: 0.0373
# Epoch 33/50
# 64/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172 Epoch 33: Perda Treinamento: 0.0176, Acurácia Treinamento: 0.9824, Perda Validação: 0.0402, Acurácia Validação: 0.9598
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0172 - val_loss: 0.0402
# Epoch 34/50
# 45/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170Epoch 34: Perda Treinamento: 0.0174, Acurácia Treinamento: 0.9826, Perda Validação: 0.0341, Acurácia Validação: 0.9659
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0171 - val_loss: 0.0341
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180Epoch 35: Perda Treinamento: 0.0179, Acurácia Treinamento: 0.9821, Perda Validação: 0.0367, Acurácia Validação: 0.9633
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0180 - val_loss: 0.0367
# Epoch 36/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170Epoch 36: Perda Treinamento: 0.0171, Acurácia Treinamento: 0.9829, Perda Validação: 0.0402, Acurácia Validação: 0.9598
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0171 - val_loss: 0.0402
# Epoch 37/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164Epoch 37: Perda Treinamento: 0.0169, Acurácia Treinamento: 0.9831, Perda Validação: 0.0373, Acurácia Validação: 0.9627
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0165 - val_loss: 0.0373
# Epoch 38/50
# 66/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175Epoch 38: Perda Treinamento: 0.0169, Acurácia Treinamento: 0.9831, Perda Validação: 0.0409, Acurácia Validação: 0.9591
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0175 - val_loss: 0.0409
# Epoch 39/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177Epoch 39: Perda Treinamento: 0.0170, Acurácia Treinamento: 0.9830, Perda Validação: 0.0418, Acurácia Validação: 0.9582
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176 - val_loss: 0.0418
# Epoch 40/50
# 62/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166Epoch 40: Perda Treinamento: 0.0168, Acurácia Treinamento: 0.9832, Perda Validação: 0.0341, Acurácia Validação: 0.9659
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0166 - val_loss: 0.0341
# Epoch 41/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169Epoch 41: Perda Treinamento: 0.0170, Acurácia Treinamento: 0.9830, Perda Validação: 0.0429, Acurácia Validação: 0.9571
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0169 - val_loss: 0.0429
# Epoch 42/50
# 43/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175Epoch 42: Perda Treinamento: 0.0169, Acurácia Treinamento: 0.9831, Perda Validação: 0.0397, Acurácia Validação: 0.9603
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - val_loss: 0.0397
# Epoch 43/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170Epoch 43: Perda Treinamento: 0.0170, Acurácia Treinamento: 0.9830, Perda Validação: 0.0446, Acurácia Validação: 0.9554
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0170 - val_loss: 0.0446
# Epoch 44/50
# 46/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164Epoch 44: Perda Treinamento: 0.0169, Acurácia Treinamento: 0.9831, Perda Validação: 0.0418, Acurácia Validação: 0.9582
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0166 - val_loss: 0.0418
# Epoch 45/50
# 65/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169Epoch 45: Perda Treinamento: 0.0170, Acurácia Treinamento: 0.9830, Perda Validação: 0.0424, Acurácia Validação: 0.9576
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0169 - val_loss: 0.0424
# Epoch 46/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167Epoch 46: Perda Treinamento: 0.0169, Acurácia Treinamento: 0.9831, Perda Validação: 0.0386, Acurácia Validação: 0.9614
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0167 - val_loss: 0.0386
# Epoch 47/50
# 44/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168Epoch 47: Perda Treinamento: 0.0167, Acurácia Treinamento: 0.9833, Perda Validação: 0.0442, Acurácia Validação: 0.9558
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167 - val_loss: 0.0442
# Epoch 48/50
# 67/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167Epoch 48: Perda Treinamento: 0.0162, Acurácia Treinamento: 0.9838, Perda Validação: 0.0429, Acurácia Validação: 0.9571
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0166 - val_loss: 0.0429
# Epoch 49/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172Epoch 49: Perda Treinamento: 0.0167, Acurácia Treinamento: 0.9833, Perda Validação: 0.0449, Acurácia Validação: 0.9551
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0172 - val_loss: 0.0449
# Epoch 50/50
# 60/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171Epoch 50: Perda Treinamento: 0.0167, Acurácia Treinamento: 0.9833, Perda Validação: 0.0420, Acurácia Validação: 0.9580
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0171 - val_loss: 0.0420
# 5500/5500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step

# %%
# Exibir os resultados SBM e AAKR
print('                                      ')
print('---------------------------------------')
print(f"SBM (MSE - Erro de Reconstrução): {sbm_value:.4f}")
#print('                                      ')
#print('---------------------------------------')
print(f"Acurácia SBM (1 - Erro de Reconstrução): {accuracy_sbm:.4f}")
#print('                                      ')
#print('---------------------------------------')
print(f"AAKR (MSE - Erro de Reconstrução): {aakr_value:.4f}")
#print('                                      ')
#print('---------------------------------------')
print(f"Acurácia AAKR (1 - Erro de Reconstrução): {accuracy_aakr:.4f}")
#print('                                      ')
#print('---------------------------------------')
# Out:
#
# ---------------------------------------
# SBM (MSE - Erro de Reconstrução): 0.0371
# Acurácia SBM (1 - Erro de Reconstrução): 0.9629
# AAKR (MSE - Erro de Reconstrução): 0.0000
# Acurácia AAKR (1 - Erro de Reconstrução): 1.0000

# %%
# Plotar gráficos de perda e acurácia
plt.figure(figsize=(20, 10))

# Plotar curvas de perda
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Perda Treinamento SBM')
plt.plot(history.history['val_loss'], label='Perda Validação SBM')
plt.title('Curva de Perda - SBM')
plt.xlabel('Época')
plt.ylabel('Perda (MSE)')
plt.legend()

# Plotar curvas de acurácia
plt.subplot(1, 2, 2)
plt.plot([1 - x for x in history.history['loss']], label='Acurácia Treinamento SBM')  # Inverso da perda como acurácia
plt.plot([1 - x for x in history.history['val_loss']], label='Acurácia Validação SBM')  # Inverso da perda como acurácia
plt.title('Curva de Acurácia - SBM')
plt.xlabel('Época')
plt.ylabel('Acurácia (1 - Perda)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Verificando valores calculados
if sbm_value is None or aakr_value is None:
    print("Erro ao calcular SBM ou AAKR!")
else:
    # Gráficos de comparação SBM e AAKR
    plt.figure(figsize=(10, 6))

    # Gráfico de barras comparando os erros (MSE) de SBM e AAKR
    plt.subplot(1, 2, 1)
    plt.bar(['SBM', 'AAKR'], [sbm_value, aakr_value], color=['blue', 'orange'])
    plt.title('Comparação de Erros de Reconstrução (MSE)')
    plt.ylabel('Erro de Reconstrução (MSE)')

    # Gráfico de barras comparando as acurácias de SBM e AAKR
    plt.subplot(1, 2, 2)
    plt.bar(['SBM', 'AAKR'], [accuracy_sbm, accuracy_aakr], color=['green', 'red'])
    plt.title('Comparação de Acurácias')
    plt.ylabel('Acurácia (1 - MSE)')

    plt.tight_layout()
    plt.show()

# %%
# Gráfico de perda e acurácia
plt.figure(figsize=(20, 5))

# Plotar as curvas de perda para o SBM
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Perda Treinamento SBM')
plt.plot(history.history['val_loss'], label='Perda Validação SBM')
plt.title('Curva de Perda - SBM')
plt.xlabel('Época')
plt.ylabel('Perda (MSE)')
plt.legend()
